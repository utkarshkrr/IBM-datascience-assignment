# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# 2-title.png
# ![image.png](attachment:33c895ba-bd5d-4979-9c55-64db42a820f5.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# 3-intro.png
# ![3-intro.png](attachment:736f5b4b-dd90-4b7c-9b64-1b363616fb33.png)

# %% [markdown]
# Some of the popular laguages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia

# %% [markdown]
# 4-dslanguages.png
# ![4-dslanguages.png](attachment:46d7778a-2354-4b5e-9527-bcce86be51ad.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn

# %% [markdown]
# 5-dslibraries.png
# ![5-dslibraries.png](attachment:6d588eec-4857-4433-8f52-c95e180a34f8.png)

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook|
# | RStudio|
# | Apache|

# %% [markdown]
# 6-dstools.png
# ![6-dstools.png](attachment:89d85526-adc6-4ab5-967c-e4d85d89b5e5.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# 7-introarithmetic.png
# ![7-introarithmetic.png](attachment:1d5dda82-b8d8-4e8a-81a7-b0a7f53ec3f6.png)

# %%
# This a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# 8-multiplyandaddintegers.png
# ![8-multiplyandaddintegers.png](attachment:f9538ffb-e1bd-426c-b4b9-e99ffa03e252.png)

# %%
# This will convert 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# 9-hourstominutes.png
# ![9-hourstominutes.png](attachment:0debe6cf-3df3-412c-9c82-0f1af961dfd0.png)

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List commonly used libraries in Data Science
# - Create and evaluate arithmetic expressions in Python
# - Use markdown and code cells in Jupyter Notebooks
# - Share notebook via GitHub

# %% [markdown]
# 10-objectives.png
# ![10-objectives.png](attachment:4982a7b2-11e7-4b86-b3a7-985d113cfecb.png)

# %% [markdown]
# ## Author
# Utkarsh Kumar

# %% [markdown]
# 11-authordetails.png
# ![11-authordetails.png](attachment:5a194f8c-3a13-4c7c-af2c-e1b7822acf99.png)
